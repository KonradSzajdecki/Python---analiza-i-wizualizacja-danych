# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import seaborn as sns
import matplotlib.dates as mdates
from datetime import datetime

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-828ce977-e8ce-4ea8-8e5b-437b3a53dfa3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-828ce977-e8ce-4ea8-8e5b-437b3a53dfa3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving zasilaczL23.csv to zasilaczL23.csv

# %%
zas=pd.read_csv('zasilaczL23.csv',delimiter=';',decimal=',')

# %%
zas.describe()
# Out:
#         Unnamed: 0  J23.R1X.TOP.TP.TC.PV  ...     Humidity  FTA$SumDefect.L23
# count  3858.000000           3858.000000  ...  3858.000000        3858.000000
# mean   1936.276827           1259.698892  ...    83.608719          82.240798
# std    1123.383732             11.396501  ...     9.341457          33.583701
# min       1.000000           1209.799316  ...    52.500000          10.000000
# 25%     965.250000           1258.540253  ...    79.000000          61.000000
# 50%    1929.500000           1260.196289  ...    86.600000          78.000000
# 75%    2893.750000           1267.340240  ...    90.100000          99.000000
# max    3895.000000           1284.707397  ...    95.000000         497.000000
#
# [8 rows x 74 columns]

# %%
zas[['FTA$SumDefect.L23']].describe()
# Out:
#        FTA$SumDefect.L23
# count        3858.000000
# mean           82.240798
# std            33.583701
# min            10.000000
# 25%            61.000000
# 50%            78.000000
# 75%            99.000000
# max           497.000000

# %%
#porównanie parametru "ciśnienie powietrza do spalania z lewej strony sekcji Refiner1 [mbar]" oraz sumy wadliwy wyrobów
zas[['J23.R1L.CB.PR.PV','FTA$SumDefect.L23']].describe()
# Out:
#        J23.R1L.CB.PR.PV  FTA$SumDefect.L23
# count       3858.000000        3858.000000
# mean           5.498499          82.240798
# std            1.225691          33.583701
# min            4.731428          10.000000
# 25%            5.071987          61.000000
# 50%            5.305664          78.000000
# 75%            5.353074          99.000000
# max           14.140923         497.000000

# %%
dane_zwykle = zas.copy()

# %%
dane=zas.copy()
dane_y=dane.pop('FTA$SumDefect.L23')
dane_stats = dane.describe()
dane_stats = dane_stats.transpose()


#pierwsza metoda
def metoda1(x):
  return (x - dane_stats['mean']) / dane_stats['std']

dane1=metoda1(dane)

#druga metoda, skalowanie do wartości od 0 do 1
def metoda2(x):
  return (x - dane_stats['min']) / (dane_stats['max'] - dane_stats['min'])

dane2=metoda2(dane)

# %%
y_bin=dane_y.copy()
n=0
for i,a in enumerate(y_bin):
  if a<30:
    y_bin[i]=0
  elif a>=30:
    y_bin[i]=1

# %%
zas.hist(bins=100,figsize=(25,25))
plt.show()

# %%
dane_zwykle = zas.copy()
plt.figure(figsize=(12,8))
kolumny = ["J23.R1X.TOP.TP.TC.PV",  "J23.R1X.BTM.TP.TC.PV"]

for col in kolumny:
    plt.hist(dane_zwykle[col], density=False, alpha=0.5) #density zamienia zwykłe liczby na ułamek
plt.title("Sekcja Refiner1",fontsize=30)
plt.xlabel("Temperatura",fontsize=15)
plt.ylabel("Liczba obserwacji",fontsize=15)
plt.show()

# %%
dane_zwykle = zas.copy()
plt.figure(figsize=(12,8))
kolumny = ["J23.R2C.TOP.TP.TC.PV",  "J23.R2C.BTM.TP.TC.PV"]

for col in kolumny:
    plt.hist(dane_zwykle[col], density=False, alpha=0.5) #density zamienia zwykłe liczby na ułamek
plt.title("Sekcja Refiner2",fontsize=30)
plt.xlabel("Temperatura",fontsize=15)
plt.ylabel("Liczba obserwacji",fontsize=15)
plt.show()

# %%
dane_zwykle = zas.copy()
plt.figure(figsize=(12,8))
kolumny = ["J23.A1C.TOP.TP.TC.PV",  "J23.A1C.BTM.TP.TC.PV"]

for col in kolumny:
    plt.hist(dane_zwykle[col], density=False, alpha=0.5) #density zamienia zwykłe liczby na ułamek
plt.title("Sekcja Alcove",fontsize=30)
plt.xlabel("Temperatura",fontsize=15)
plt.ylabel("Liczba obserwacji",fontsize=15)
plt.show()

# %%
dane_zwykle = zas.copy()
plt.figure(figsize=(12,8))
kolumny = ["J23.BC.TOP.TP.TC.PV",  "J23.BC.BTM.TP.TC.PV"]

for col in kolumny:
    plt.hist(dane_zwykle[col], density=False, alpha=0.5) #density zamienia zwykłe liczby na ułamek
plt.title("Sekcja Back",fontsize=30)
plt.xlabel("Temperatura",fontsize=15)
plt.ylabel("Liczba obserwacji",fontsize=15)
plt.show()

# %%
dane_zwykle = zas.copy()
plt.figure(figsize=(12,8))
kolumny = ["J23.MC.TOP.TP.TC.PV",  "J23.MC.BTM.TP.TC.PV"]

for col in kolumny:
    plt.hist(dane_zwykle[col], density=False, alpha=0.5) #density zamienia zwykłe liczby na ułamek
plt.title("Sekcja Middle",fontsize=30)
plt.xlabel("Temperatura",fontsize=15)
plt.ylabel("Liczba obserwacji",fontsize=15)
plt.show()

# %%
dane_zwykle = zas.copy()
plt.figure(figsize=(12,8))
kolumny = ["J23.FC.TOP.TP.TC.PV",  "J23.FC.BTM.TP.TC.PV"]

for col in kolumny:
    plt.hist(dane_zwykle[col], density=False, alpha=0.5) #density zamienia zwykłe liczby na ułamek
plt.title("Sekcja Front",fontsize=30)
plt.xlabel("Temperatura",fontsize=15)
plt.ylabel("Liczba obserwacji",fontsize=15)
plt.show()

# %%
dane_zwykle = zas.copy()
plt.figure( figsize=(12,8))
kolumny = ["J23.R1X.TOP.TP.TC.PV",  "J23.R2C.TOP.TP.TC.PV", "J23.A1C.TOP.TP.TC.PV", "J23.BC.TOP.TP.TC.PV", "J23.MC.TOP.TP.TC.PV", "J23.FC.TOP.TP.TC.PV"]

for col in kolumny:
    plt.hist(dane_zwykle[col], density=False, alpha=0.5) #density zamienia zwykłe liczby na ułamek
plt.title("Sekcja 1-6",fontsize=30)
plt.xlabel("Temperatura",fontsize=15)
plt.ylabel("Liczba obserwacji",fontsize=15)
plt.show()

# %%
plt.figure(figsize=(12,8))
kolumny = ['FTA$SumDefect.L23']
for col in kolumny:
    plt.hist(dane_zwykle[col], alpha=0.5,bins=100)
plt.title("Rozkład wartości ilości wadliwych wyrobów",fontsize=17.5)
plt.xlabel("Wartość", fontsize=15)
plt.ylabel("Częstotliwość",fontsize=15)
plt.show()

# %%
plt.figure(figsize=(12,8))
kolumny = ["FN_STK.CV.PV","J23.FC.TOP.TP.SP", "J23.R1.CW.PV","Humidity", "Pressure", "Temperature"]
for col in kolumny:
    sns.kdeplot(dane_zwykle[col], shade=True)
plt.title("Rozkłady wybranych zmiennych bez standaryzacji",fontsize=20)

plt.show()

# %%
plt.figure(figsize=(12,8))
kolumny = ["FN_STK.CV.PV","J23.FC.TOP.TP.SP", "J23.R1.CW.PV","Humidity", "Pressure", "Temperature"]
for col in kolumny:
    sns.kdeplot(dane1[col],shade=True)
plt.title("Rozkłady wybranych zmiennych po standaryzacji",fontsize=20)

plt.show()

# %%
sns.distplot(dane_zwykle['J23.R1X.TOP.TP.TC.PV'])
sns.distplot(dane_zwykle['J23.R1X.BTM.TP.TC.PV']);

# %%
#with sns.axes_style('white'):
#    sns.jointplot("J23.R1X.TOP.TP.TC.PV",  "J23.FC.TOP.TP.TC.PV", data=dane_zwykle, kind='hex')

# %%
#with sns.axes_style('white'):
#    sns.jointplot("J23.R1X.TOP.TP.TC.PV",  "J23.R1X.BTM.TP.TC.PV", data=dane_zwykle, kind='kde');

# %%
#with sns.axes_style('white'):
#    sns.jointplot("J23.R1X.TOP.TP.TC.PV",  "J23.R2C.TOP.TP.TC.PV", data=dane_zwykle, kind='hex')

# %%
#with sns.axes_style('white'):
#    sns.jointplot("J23.R1X.TOP.TP.TC.PV",  "J23.FR.TOP.TP.TC.PV", data=dane_zwykle, kind='hex')

# %%
#sns.jointplot("J23.R1X.TOP.TP.TC.PV",  "J23.R1X.BTM.TP.TC.PV", data=dane_zwykle, kind='reg');

# %%
a=sns.catplot("J2F.GL.LEV.PV", data=dane_zwykle, color = "red", kind="box" )

a.set_xlabels("J2F.GL.LEV.PV")

# %%
a=sns.catplot("J23.MC.TOP.TP.SP", data=dane_zwykle, color="green", kind="box")

a.set_xlabels("J23.MC.TOP.TP.SP")

# %%
a=sns.catplot("FN_BTM_TP3_TC.PV", data=dane_zwykle, color = "yellow", kind="box")

a.set_xlabels("FN_BTM_TP3_TC.PV")

# %%
a=sns.catplot("J23.R1X.TOP.TP.TC.PV", data=dane_zwykle, color="yellow", kind="box")

a.set_xlabels("dsfdfsdsfdfs")

# %%
a=sns.catplot("J23.R1X.BTM.TP.TC.PV", data=dane_zwykle, color="yellow", kind="box")

a.set_xlabels("dsfdfsdsfdfs")

# %%
a=sns.catplot("J23.R2C.TOP.TP.TC.PV", data=dane_zwykle, color="yellow", kind="box")

a.set_xlabels("dsfdfsdsfdfs")

# %%
a=sns.catplot("J23.R2C.BTM.TP.TC.PV", data=dane_zwykle, color="yellow", kind="box")

a.set_xlabels("dsfdfsdsfdfs")

# %%
a=sns.catplot("J23.A1C.TOP.TP.TC.PV", data=dane_zwykle, color="yellow", kind="box")

a.set_xlabels("dsfdfsdsfdfs")

# %%
a=sns.catplot("J23.A1C.BTM.TP.TC.PV", data=dane_zwykle, color="yellow", kind="box")

a.set_xlabels("dsfdfsdsfdfs")

# %%
a=sns.catplot("J23.MC.TOP.TP.TC.PV", data=dane_zwykle, color="yellow", kind="box")

a.set_xlabels("dsfdfsdsfdfs")

# %%
a=sns.catplot("J23.MC.BTM.TP.TC.PV", data=dane_zwykle, color="yellow", kind="box")

a.set_xlabels("dsfdfsdsfdfs")

# %%
a=sns.catplot("J23.BC.BTM.TP.TC.PV", data=dane_zwykle, color="yellow", kind="box")

a.set_xlabels("dsfdfsdsfdfs")

# %%
a=sns.catplot("J23.BC.TOP.TP.TC.PV", data=dane_zwykle, color="yellow", kind="box")

a.set_xlabels("dsfdfsdsfdfs")

# %%
a=sns.catplot("J23.FR.BTM.TP.TC.PV", data=dane_zwykle, color="yellow", kind="box")

a.set_xlabels("dsfdfsdsfdfs")

# %%
a=sns.catplot("J23.FR.TOP.TP.TC.PV", data=dane_zwykle, color="yellow", kind="box")

a.set_xlabels("dsfdfsdsfdfs")

# %%
a=sns.catplot("J23.FL.CB.PR.PV", data=dane_zwykle, color="yellow", kind="box")

a.set_xlabels("dsfdfsdsfdfs")

# %%
a=sns.catplot("J23.R1L.CB.PR.PV", data=dane_zwykle, color="yellow", kind="box")

a.set_xlabels("dsfdfsdsfdfs")

# %%
zas.hist("Humidity", bins=29,figsize=(3.5,4))
plt.title("Humidity",fontsize=10)
plt.xlabel("",fontsize=10)
plt.ylabel("Liczba obserwacji",fontsize=8)
plt.show()

# %%
zas.hist("J23.R2C.BTM.TP.TC.PV", bins=29,figsize=(3.5,4))
plt.title("J23.FR.TOP.TP.TC.PV",fontsize=10)
plt.xlabel("",fontsize=8)
plt.ylabel("Liczba obserwacji",fontsize=8)
plt.show()

# %%
zas.hist("J2F.GL.LEV.PV", bins=29,figsize=(3.5,4))
plt.title("J2F.GL.LEV.PV",fontsize=10)
plt.xlabel("",fontsize=8)
plt.ylabel("Liczba obserwacji",fontsize=8)
plt.show()

# %%
zas.hist("J23.M1.CW.TP.PV", bins=29,figsize=(3.5,4))
plt.title("J23.M1.CW.TP.PV",fontsize=10)
plt.xlabel("",fontsize=8)
plt.ylabel("Liczba obserwacji",fontsize=8)
plt.show()

# %%
zas.hist("FN_STK.CV.PV", bins=29,figsize=(3.5,4))
plt.title("FN_STK.CV.PV",fontsize=10)
plt.xlabel("",fontsize=8)
plt.ylabel("Liczba obserwacji",fontsize=8)
plt.show()

# %%
zas.hist("J23.A1C.BTM.TP.TC.PV", bins=29,figsize=(3.5,4))
plt.title("J23.A1C.BTM.TP.TC.PV",fontsize=10)
plt.xlabel("",fontsize=8)
plt.ylabel("Liczba obserwacji",fontsize=8)
plt.show()

# %%
zas.hist("J23.R2C.BTM.TP.TC.PV", bins=40,figsize=(3.5,2.5))
plt.title("J23.R2C.BTM.TP.TC.PV",fontsize=10)
plt.xlabel("",fontsize=8)
plt.ylabel("Liczba obserwacji",fontsize=8)
plt.show()

# %%
zas.hist("Pressure", bins=50,figsize=(3.5,2.5))
plt.title("Pressure",fontsize=10)
plt.xlabel("",fontsize=8)
plt.ylabel("Liczba obserwacji",fontsize=8)
plt.show()

# %%
#korelaja - mapa ciepła
corr_matrix = zas.corr()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# ...

# %%
#bwr, coolwarm,seismic,RdYlBu,RdYlGn, viridis
plt.figure(figsize=(20,13))
sns.heatmap(corr_matrix,cmap='coolwarm')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(corr_matrix,cmap='coolwarm')
plt.show()

# %%
d=pd.to_datetime(zas['Time'])

fig = plt.figure(figsize=(15,7.5))
ax = fig.add_subplot(111)

ax.xaxis.set_minor_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

ax.plot(d, zas['FTA$SumDefect.L23'],color='r')

fig.autofmt_xdate()
plt.xlim(
    xmin=datetime(2017, 10, 17),
    xmax=datetime(2017, 11, 13)
)
ax.grid(True)

plt.show()

# %%
d=pd.to_datetime(zas['Time'])

fig = plt.figure(figsize=(15,7.5))
ax = fig.add_subplot(111)

ax.xaxis.set_minor_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

ax.plot(d, zas['FTA$SumDefect.L23'],color='y')
plt.axhline(y=30, color='r', linestyle='-', lw=2)

fig.autofmt_xdate()
plt.xlim(
    xmin=datetime(2017, 10, 17),
    xmax=datetime(2017, 11, 13)
)
ax.grid(True)

plt.show()

# %%
#1 sekcja, do opisania!

d=pd.to_datetime(zas['Time'])

fig = plt.figure(figsize=(15,7.5))
ax = fig.add_subplot(111)

ax.xaxis.set_minor_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

#refiner 1
ax.plot(d, zas['J23.R1X.TOP.TP.TC.PV'], label='górna część')
ax.plot(d, zas['J23.R1X.BTM.TP.TC.PV'], label='dolna część')
ax.plot(d, zas['J23.R1X.TOP.TP.SP'], label='zadana')



fig.autofmt_xdate()
plt.xlim(xmin=datetime(2017, 10, 17),xmax=datetime(2017, 11, 13)) #pełen okres czasu
ax.grid(True)

plt.legend()
plt.show()

# %%
import matplotlib.dates as mdates
from datetime import datetime

d=pd.to_datetime(zas['Time'])

fig = plt.figure(figsize=(15,7.5))
ax = fig.add_subplot(111)

ax.xaxis.set_minor_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

#refiner 2
ax.plot(d, zas['J23.R2C.TOP.TP.TC.PV'], label='górna część')
ax.plot(d, zas['J23.R2C.BTM.TP.TC.PV'], label='dolna część')
ax.plot(d, zas['J23.R2C.TOP.TP.SP'], label='zadana')


fig.autofmt_xdate()
plt.xlim(xmin=datetime(2017, 10, 17),xmax=datetime(2017, 11, 13)) #pełen okres czasu
ax.grid(True)

plt.legend()
plt.show()

# %%
import matplotlib.dates as mdates
from datetime import datetime

d=pd.to_datetime(zas['Time'])

fig = plt.figure(figsize=(15,7.5))
ax = fig.add_subplot(111)

ax.xaxis.set_minor_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

#alcove
ax.plot(d, zas['J23.A1C.TOP.TP.TC.PV'], label='górna część')
ax.plot(d, zas['J23.A1C.BTM.TP.TC.PV'], label='dolna część')
ax.plot(d, zas['J23.A1C.TOP.TP.SP'], label='zadana')



fig.autofmt_xdate()
plt.xlim(xmin=datetime(2017, 10, 17),xmax=datetime(2017, 11, 13)) #pełen okres czasu
ax.grid(True)

plt.legend()
plt.show()

# %%
import matplotlib.dates as mdates
from datetime import datetime

d=pd.to_datetime(zas['Time'])

fig = plt.figure(figsize=(15,7.5))
ax = fig.add_subplot(111)

ax.xaxis.set_minor_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

#sekcja BACK
ax.plot(d, zas['J23.BC.TOP.TP.TC.PV'], label='górna część')
ax.plot(d, zas['J23.BC.BTM.TP.TC.PV'], label='dolna część')
ax.plot(d, zas['J23.BC.TOP.TP.SP'], label='zadana')



fig.autofmt_xdate()
plt.xlim(xmin=datetime(2017, 10, 17),xmax=datetime(2017, 11, 13)) #pełen okres czasu
ax.grid(True)

plt.legend()
plt.show()

# %%
import matplotlib.dates as mdates
from datetime import datetime

d=pd.to_datetime(zas['Time'])

fig = plt.figure(figsize=(15,7.5))
ax = fig.add_subplot(111)

ax.xaxis.set_minor_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

#sekcja middle
ax.plot(d, zas['J23.MC.TOP.TP.TC.PV'], label='górna część')
ax.plot(d, zas['J23.MC.BTM.TP.TC.PV'], label='dolna część')
ax.plot(d, zas['J23.MC.TOP.TP.SP'], label='zadana')



fig.autofmt_xdate()
plt.xlim(xmin=datetime(2017, 10, 17),xmax=datetime(2017, 11, 13)) #pełen okres czasu
ax.grid(True)

plt.legend()
plt.show()

# %%
import matplotlib.dates as mdates
from datetime import datetime

d=pd.to_datetime(zas['Time'])

fig = plt.figure(figsize=(15,7.5))
ax = fig.add_subplot(111)

ax.xaxis.set_minor_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

#sekcja front
ax.plot(d, zas['J23.FL.TOP.TP.TC.PV'], label='górna, lewa część sekcji front')
ax.plot(d, zas['J23.FL.BTM.TP.TC.PV'], label='dolna, lewa częśćsekcji front')
ax.plot(d, zas['J23.FC.TOP.TP.TC.PV'], label='górna, centralna temp sekcji front')
ax.plot(d, zas['J23.FC.BTM.TP.TC.PV'], label='dolna, centralna temp sekcji font')
ax.plot(d, zas['J23.FR.TOP.TP.TC.PV'], label='górna, prawa temp sekcji')
ax.plot(d, zas['J23.FR.BTM.TP.TC.PV'], label='dolna, prawa część sekcji')
ax.plot(d, zas['J23.FC.TOP.TP.SP'], label='zadana')


fig.autofmt_xdate()
plt.xlim(xmin=datetime(2017, 10, 17),xmax=datetime(2017, 11, 13)) #pełen okres czasu
ax.grid(True)

plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(15,7.5))
ax = fig.add_subplot(111)

#co 8 godzin
ax.xaxis.set_major_locator(mdates.HourLocator(interval=8))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d-%H-%M'))


#sekcja front
ax.plot(d, zas['J23.FL.TOP.TP.TC.PV'], label='górna, lewa część sekcji front')
ax.plot(d, zas['J23.FL.BTM.TP.TC.PV'], label='dolna, lewa częśćsekcji front')
ax.plot(d, zas['J23.FC.TOP.TP.TC.PV'], label='górna, centralna temp sekcji front')
ax.plot(d, zas['J23.FC.BTM.TP.TC.PV'], label='dolna, centralna temp sekcji font')
ax.plot(d, zas['J23.FR.TOP.TP.TC.PV'], label='górna, prawa temp sekcji')
ax.plot(d, zas['J23.FR.BTM.TP.TC.PV'], label='dolna, prawa część sekcji')
ax.plot(d, zas['J23.FC.TOP.TP.SP'], label='zadana')

fig.autofmt_xdate()
plt.xlim(xmin=datetime(2017, 11, 6),xmax=datetime(2017, 11, 7))  #zmianowy-3 zmiany po 8h
ax.grid(True)

plt.legend()
plt.show()

# %%
import matplotlib.dates as mdates
from datetime import datetime

d=pd.to_datetime(zas['Time'])

fig = plt.figure(figsize=(15,7.5))
ax = fig.add_subplot(111)

ax.xaxis.set_minor_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

#sekcja front
ax.plot(d, zas['J23.FL.TOP.TP.TC.PV'], label='górna, lewa część sekcji front')
ax.plot(d, zas['J23.FL.BTM.TP.TC.PV'], label='dolna, lewa częśćsekcji front')
ax.plot(d, zas['J23.FC.TOP.TP.TC.PV'], label='górna, centralna temp sekcji front')
ax.plot(d, zas['J23.FC.BTM.TP.TC.PV'], label='dolna, centralna temp sekcji font')
ax.plot(d, zas['J23.FR.TOP.TP.TC.PV'], label='górna, prawa temp sekcji')
ax.plot(d, zas['J23.FR.BTM.TP.TC.PV'], label='dolna, prawa część sekcji')
ax.plot(d, zas['J23.FC.TOP.TP.SP'], label='zadana')


fig.autofmt_xdate()
plt.xlim(xmin=datetime(2017, 11, 6),xmax=datetime(2017, 11, 11)) 
ax.grid(True)

plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(15,7.5))
ax = fig.add_subplot(111)


ax.xaxis.set_major_locator(mdates.HourLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d-%H-%M'))


#sekcja front
ax.plot(d, zas['J23.FL.TOP.TP.TC.PV'], label='górna, lewa część sekcji front')
ax.plot(d, zas['J23.FL.BTM.TP.TC.PV'], label='dolna, lewa częśćsekcji front')
ax.plot(d, zas['J23.FC.TOP.TP.TC.PV'], label='górna, centralna temp sekcji front')
ax.plot(d, zas['J23.FC.BTM.TP.TC.PV'], label='dolna, centralna temp sekcji font')
ax.plot(d, zas['J23.FR.TOP.TP.TC.PV'], label='górna, prawa temp sekcji')
ax.plot(d, zas['J23.FR.BTM.TP.TC.PV'], label='dolna, prawa część sekcji')
ax.plot(d, zas['J23.FC.TOP.TP.SP'], label='zadana')

fig.autofmt_xdate()
plt.xlim(xmin=datetime(2017, 11, 6),xmax=datetime(2017, 11, 7))  
ax.grid(True)

plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(15,7.5))
ax = fig.add_subplot(111)

#co 8 godzin = interval =8
ax.xaxis.set_major_locator(mdates.HourLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d-%H-%M'))


#sekcja front
ax.plot(d, zas['FTA$SumDefect.L23'], label='defekty')
ax.plot(d, zas['J23.R1X.TOP.TP.TC.PV'], label='central refiner1')
ax.plot(d, zas['J23.FC.TOP.TP.TC.PV'], label='central front')

fig.autofmt_xdate()
plt.xlim(xmin=datetime(2017, 11, 9),xmax=datetime(2017, 11, 10))  #co godzine 
ax.grid(True)

plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(15,7.5))
ax = fig.add_subplot(111)

#co 8 godzin = interval =8
ax.xaxis.set_major_locator(mdates.HourLocator(interval=8))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d-%H-%M'))


#sekcja front
ax.plot(d, zas['FTA$SumDefect.L23'], label='górna, lewa część sekcji front')
ax.plot(d, zas['J23.R1X.TOP.TP.TC.PV'], label='górna, lewa część sekcji front')
ax.plot(d, zas['J23.FC.TOP.TP.TC.PV'], label='górna, lewa część sekcji front')

fig.autofmt_xdate()
plt.xlim(xmin=datetime(2017, 11, 9),xmax=datetime(2017, 11, 10))  #co godzine 
ax.grid(True)

plt.legend()
plt.show()

# %%
attr = ["J23.R1X.TOP.TP.TC.PV", "J23.R2C.TOP.TP.TC.PV", "J23.A1C.TOP.TP.TC.PV", "J23.BC.TOP.TP.TC.PV", "J23.MC.TOP.TP.TC.PV", "J23.FL.TOP.TP.TC.PV"]
scatter_matrix(zas[attr], figsize=(25,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc3e2424f90>,
# ...
#       dtype=object)

# %%
attr2 = ["J23.R1X.BTM.TP.TC.PV", "J23.R2C.BTM.TP.TC.PV", "J23.A1C.BTM.TP.TC.PV", "J23.BC.BTM.TP.TC.PV", "J23.MC.BTM.TP.TC.PV", "J23.FL.BTM.TP.TC.PV"]
scatter_matrix(zas[attr2], figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc3e4004790>,
# ...
#       dtype=object)

# %%
plt.figure(figsize=(2.5,15))
sns.heatmap(corr_matrix["FTA$SumDefect.L23"].sort_values(ascending=False).to_frame(), annot=True, cmap='viridis')
plt.show()

# %%
corr_matrix["FTA$SumDefect.L23"].sort_values(ascending=False)[:10]
# Out:
# FTA$SumDefect.L23       1.000000
# Z2.KW                   0.311984
# Z3.KW                   0.299502
# J23.R1X.TOP.TP.TC.PV    0.299359
# J23.R1X.BTM.TP.TC.PV    0.213224
# J23.BC.TOP.TP.TC.PV     0.212634
# J23.BC.TOP.TP.SP        0.206313
# J23.M1.CW.TP.PV         0.181707
# J23.A1L.CV.PV           0.161390
# J23.R1X.TOP.TP.SP       0.160836
# Name: FTA$SumDefect.L23, dtype: float64

# %%
plt.figure(figsize=(2.5,5))
sns.heatmap(corr_matrix["FTA$SumDefect.L23"].sort_values(ascending=False)[:20].to_frame(), annot=True, cmap='viridis')
plt.show()
